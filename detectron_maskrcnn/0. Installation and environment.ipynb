# %%
# In anaconda Prompt:
#!conda create -n detectron_env python=3.10 -y
#!conda activate detectron_env

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install opencv-python
# !pip install pycocotools
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 GB 985.5 kB/s eta 0:47:39
#    ---------------------------------------- 0.0/2.8 GB 1.4 MB/s eta 0:33:33
#    ---------------------------------------- 0.0/2.8 GB 1.4 MB/s eta 0:33:33
#    ---------------------------------------- 0.0/2.8 GB 1.2 MB/s eta 0:37:47
#    ---------------------------------------- 0.0/2.8 GB 1.2 MB/s eta 0:37:47
#    ---------------------------------------- 0.0/2.8 GB 1.1 MB/s eta 0:41:30
#    ---------------------------------------- 0.0/2.8 GB 1.1 MB/s eta 0:41:58
#    ---------------------------------------- 0.0/2.8 GB 1.4 MB/s eta 0:33:33
# ...

# %%
#Install Microsoft C++ visual tools for windows. This will allow to install Detectron. If it is already there go to the step below.
# https://visualstudio.microsoft.com/visual-cpp-build-tools/  
# After downloading install Desktop development with C++

# %%
# Install detectron:
# cd C:\path\to\your\workspace
# git clone https://github.com/facebookresearch/detectron2.git
# cd detectron2
# python -m pip install -e .
